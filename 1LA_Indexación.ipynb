# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("listings.csv") # CAMBIAR EL NOMBRE 
df
# Out:
#                         id                                       listing_url  \
# 0                     2708                 https://www.airbnb.com/rooms/2708
# 1                     2732                 https://www.airbnb.com/rooms/2732
# 2                     2864                 https://www.airbnb.com/rooms/2864
# 3                     6033                 https://www.airbnb.com/rooms/6033
# 4                     6931                 https://www.airbnb.com/rooms/6931
# ...                    ...                                               ...
# 45416  1443394805958459680  https://www.airbnb.com/rooms/1443394805958459680
# 45417  1443394831515560629  https://www.airbnb.com/rooms/1443394831515560629
# 45418  1443394885201303898  https://www.airbnb.com/rooms/1443394885201303898
# 45419  1443449500529637549  https://www.airbnb.com/rooms/1443449500529637549
# 45420  1443465434447227262  https://www.airbnb.com/rooms/1443465434447227262
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45421 entries, 0 to 45420
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            45421 non-null  int64
#  1   listing_url                                   45421 non-null  object
#  2   scrape_id                                     45421 non-null  int64
#  3   last_scraped                                  45421 non-null  object
#  4   source                                        45421 non-null  object
#  5   name                                          45420 non-null  object
#  6   description                                   44399 non-null  object
#  7   neighborhood_overview                         20350 non-null  object
#  8   picture_url                                   45421 non-null  object
# ...

# %%
#Filas combinadas y Todas las columnas
df= df.iloc[ :,list(range(2, 8)) + list(range(9, 19)) + list(range(21, 24)) + [26] + [28] + list(range(30, 34)) + [35] + [38] + list(range(40, 43)) + list(range(50, 57)) + list(range(61, 66)) + list(range(67, 73)) + [74] + [78] ]
df.info()

print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45421 entries, 0 to 45420
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   scrape_id                       45421 non-null  int64
#  1   last_scraped                    45421 non-null  object
#  2   source                          45421 non-null  object
#  3   name                            45420 non-null  object
#  4   description                     44399 non-null  object
#  5   neighborhood_overview           20350 non-null  object
#  6   host_id                         45421 non-null  int64
#  7   host_url                        45421 non-null  object
#  8   host_name                       45416 non-null  object
#  9   host_since                      45414 non-null  object
#  10  host_location                   34640 non-null  object
#  11  host_about                      24875 non-null  object
# ...

# %%
#Convertir array a CSV
df.to_csv("Entregable1.csv")
